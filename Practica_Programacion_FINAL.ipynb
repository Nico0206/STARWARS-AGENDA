# %%
#Practica Progra Star Wars
#Nombre: Nicolás Montesinos Recio
#Fecha de entrega: 19/04/2023

# %%
name = str(input("¡Hola! Introduce tu nombre: "))
print("¡Bienvenido a tu Agenda de Star Wars,",(name))
starwars = r"""
  ⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⠀⢀⣤⣤⣤⣤⣤⣤⣤⠀⠀⠀⠀⢠⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠀⣼⣿⣿⣿⣿⣿⣿⣿⣇⠀⠀⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⡀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣟⠛⠛⠛⠛⠛⣿⣿⣿⣿⡟⠛⠛⠛⠛⠛⢠⣿⣿⣿⣿⠿⣿⣿⣿⣿⡀⠀⠀⢸⣿⣿⣿⣿⡏⠉⠉⢉⣿⣿⣿⣿⡇⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠙⢿⣿⣿⣿⣿⣷⡀⠀⠀⠀⣿⣿⣿⣿⡇⠀⠀⠀⠀⠀⣾⣿⣿⣿⡟⠀⢻⣿⣿⣿⣧⠀⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠟⠀⠀⠀⠀⠀
⣤⣤⣤⣤⣤⣤⣤⣤⣤⣬⣿⣿⣿⣿⣿⣷⠀⠀⠀⣿⣿⣿⣿⡇⠀⠀⠀⠀⢰⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡆⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣧⣤⣤⣤⣤⣤⣤
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠏⠀⠀⠀⣿⣿⣿⣿⡇⠀⠀⠀⢀⣿⣿⣿⣿⡿⠿⠿⠿⠿⣿⣿⣿⣿⡀⢸⣿⣿⣿⣿⡇⠙⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⠿⠿⠿⠿⠿⠿⠿⠿⠿⠿⠿⠿⠟⠛⠁⠀⠀⠀⠀⠿⠿⠿⠿⠇⠀⠀⠀⠸⠿⠿⠿⠟⠀⠀⠀⠀⠀⠻⠿⠿⠿⠇⠸⠿⠿⠿⠿⠇⠀⠀⠙⠛⠿⠿⠿⠿⠿⠿⠿⠿
⢻⣿⣿⣿⣿⡄⢠⣿⣿⣿⣿⣿⡆⠀⣾⣿⣿⣿⡟⠀⢀⣾⣿⣿⣿⣿⣿⣿⡄⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣷⣶⣦⣄⠀⠀⠀⠀⣠⣶⣶⣿⣿⣿⣿⣿⣿⣿⣿
⠈⣿⣿⣿⣿⣷⣼⣿⣿⣿⣿⣿⣿⣸⣿⣿⣿⣿⠁⠀⣼⣿⣿⣿⣿⣿⣿⣿⣷⠀⠀⠀⠀⣿⣿⣿⣿⣿⠿⠿⢿⣿⣿⣿⣿⣇⠀⠀⣸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡏⠀⢠⣿⣿⣿⣿⠏⢿⣿⣿⣿⣇⠀⠀⠀⣿⣿⣿⣿⣿⣀⣀⣀⣼⣿⣿⣿⡟⠀⠀⢹⣿⣿⣿⣿⣿⣄⠀⠀⠀⠀⠀
⠀⠀⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠀⠀⣾⣿⣿⣿⣟⣀⣸⣿⣿⣿⣿⡀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⠟⠁⠀⠀⠀⠙⢿⣿⣿⣿⣿⣧⠀⠀⠀⠀
⠀⠀⠘⣿⣿⣿⣿⣿⣿⠋⣿⣿⣿⣿⣿⣿⠇⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣧⠀⠀⣿⣿⣿⣿⣿⢿⣿⣿⣿⣿⣿⣶⣶⣶⣶⣶⣶⣾⣿⣿⣿⣿⣿⠇⠀⠀⠀
⠀⠀⠀⢻⣿⣿⣿⣿⡏⠀⢹⣿⣿⣿⣿⡟⠀⢀⣿⣿⣿⣿⡟⠛⠛⠛⠛⣿⣿⣿⣿⡆⠀⣿⣿⣿⣿⣿⠀⠙⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠟⠀⠀⠀⠀
⠀⠀⠀⠈⠉⠉⠉⠉⠀⠀⠀⠉⠉⠉⠉⠁⠀⠈⠉⠉⠉⠉⠀⠀⠀⠀⠀⠉⠉⠉⠉⠉⠀⠉⠉⠉⠉⠉⠀⠀⠀⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠁⠀⠀⠀⠀⠀⠀⠀⠀

"""
print(starwars)

#Importamos paquete
import pandas as pd
df = pd.DataFrame()
#Creamos data frame
data = {"Nombre": [], "Rango": [], "Nivel Poder": [], "Alumno de": [], "Maestro de": []}
Jedis_dataFrame = pd.DataFrame(data)
#Creamos los Jedis
def Jedi():
  nombre = input("Nombre: ")
  rango = input("Rango: ")
  nivel_poder = int(input("Nivel Poder: "))
  alumno_de = input("Alumno de: ")
  maestro_de = input("Maestro de: ")
  registro_nuevo = {"Nombre": [nombre], "Rango": [rango], "Nivel Poder": [nivel_poder], "Alumno de": [alumno_de], "Maestro de": [maestro_de]}
  Jedis_dataFrame = pd.DataFrame(registro_nuevo)
  df = df.append({'Nombre': [nombre], 'Rango': [rango], 'Nivel Poder':[nivel_poder], 'Alumno de': [alumno_de], 'Maestro de': [maestro_de]}, ignore_index=True)


#Creamos los Siths con sus respectivas clases

def Sith():
  nombre_sith = input("Nombre: ")
  rango_sith = input("Rango: ")
  nivel_sith = input("Nivel Poder: ")
  alumnosith_de = input("Alumno de: ")
  maestrosith_de = input("Maestro de: ")
  Jedis_dataFrame = pd.DataFrame(registro_nuevo)
  df = df.append({'Nombre': [nombre], 'Rango': [rango], 'Nivel Poder':[nivel_poder], 'Alumno de': [alumno_de], 'Maestro de': [maestro_de]}, ignore_index=True)

#Creamos clase Jedi con sus atributos

class Jedi:
    def __init__(self, nombre, rango, nivel_poder, alumno_de, maestro_de):
        self.nombre = nombre
        self.rango = rango
        self.nivel_poder = nivel_poder
        self.alumno_de = alumno_de
        self.maestro_de = maestro_de

class Sith:
    def __init__(self, nombre, rango, nivel_poder, alumno_de, maestro_de):
        self.nombre = nombre
        self.rango = rango
        self.nivel_poder = nivel_poder
        self.alumno_de = alumno_de
        self.maestro_de = maestro_de



# Crear listas vacías para cada agenda
agenda_jedis = []
agenda_siths = []



# Definir función para añadir un nuevo sith/jedi a la agenda
def anadir_sith_o_jedi():
    print("---------------------------------------------------------")
    print("¿Desea añadir un Jedi o un Sith?")
    print("1. Jedi")
    print("2. Sith")
    print("---------------------------------------------------------")

    opcion = input("> ")

    if opcion == "1":
        if len(agenda_jedis) < 50: #Determinamos la longitud de la agenda que tiene que ser de 50 jedis como max
            nombre = input("Nombre: ")
            if any(jedi.nombre == nombre for jedi in agenda_jedis):
              print("---------------------------------------------------------")
              print(f"ERROR: {nombre} ya esta en la agenda de Jedis. Vuelva a intentarlo.")
              print("---------------------------------------------------------")
            else:
              print("Rango \n1. Padawan\n2. Caballero\n3. Maestro: ")
            aux = input("> ")
            if aux == "1":
                rango = "Padawan"
            elif aux == "2":
                rango = "Caballero"
            elif aux == "3":
                rango = "Maestro"
            else:
                print("---------------------------------------------------------")
                print("ERROR: Opción inválida. Por favor, elija una opción del menú.")
                print("---------------------------------------------------------")
                return

            alumno_de = input("Alumno de: ")
            maestro_de = input("Maestro de: ")
            nivel_poder = input("Nivel de poder: ")
            jedi = Jedi(nombre, rango, nivel_poder, alumno_de, maestro_de)
            agenda_jedis.append(jedi)
            print("---------------------------------------------------------")
            print(f"Se ha añadido a {nombre} a la agenda de Jedis.")
            print("---------------------------------------------------------")
        else:
            print("La agenda de Jedis está llena.")
    elif opcion == "2":
        if len(agenda_siths) < 50:
            nombre = input("Nombre: ")
            if any(sith.nombre == nombre for sith in agenda_siths):
              print("---------------------------------------------------------")
              print(f"Error, {nombre} ya esta en la agenda de Sith. Vuelva a intentarlo.")
              print("---------------------------------------------------------")
            else:
              print("Rango \n1. Aprendiz\n2. Darth\n3. Lord: ")#aqui no he contmplado la opción de que se de un valor distinto a 1, 2 o 3
            aux1 = input("> ")
            if aux1 == "1":
                rango = "Aprendiz"
            elif aux1 == "2":
                rango = "Darth"
            elif aux1 == "3":
                rango = "Lord"
            else:
                print("Opción inválida. Por favor, elija una opción del menú.")
                return
            alumno_de = input("Alumno de: ")
            maestro_de = input("Maestro de: ")
            nivel_poder = input("Nivel de poder: ")
            sith = Sith(nombre, rango, alumno_de, maestro_de, nivel_poder)
            agenda_siths.append(sith)
            print("---------------------------------------------------------")
            print(f"Se ha añadido a {nombre} a la agenda de Siths.")
            print("---------------------------------------------------------")
        else:
            print("---------------------------------------------------------")
            print("ERROR: La agenda de Siths está llena.")
            print("---------------------------------------------------------")
    else:
        print("---------------------------------------------------------")
        print("ERROR: Opción inválida. Por favor, elija una opción del menú.")
        print("---------------------------------------------------------")




# Definir función para modificar un sith/jedi existente
def modificar_sith_o_jedi():
    print("---------------------------------------------------------")
    print("¿Desea modificar un Jedi o un Sith?")
    print("1. Jedi")
    print("2. Sith")
    print("---------------------------------------------------------")

    opcion = input("> ")

    #Creamos la opcion de modificar un Jedi
    if opcion == "1":
        nombre = input("Nombre: ")
        for jedi in agenda_jedis:
            if jedi.nombre == nombre:
                print("---------------------------------------------------------")
                print("¿Qué desea modificar?")
                print("1. Nombre")
                print("2. Rango")
                print("3. Nivel de poder")
                print("4. Alumno de")
                print("5. Maestro de")
                print("---------------------------------------------------------")


                opcion = input("> ")

                #Modificar el nombre para un Jedi
                if opcion == "1":
                    nuevo_nombre = input("Nuevo nombre: ")
                    if any(jedi.nombre == nuevo_nombre for jedi in agenda_jedis):
                      print(f"{nuevo_nombre} ya esta en la agenda de Jedis.")
                      break
                    jedi.nombre = nuevo_nombre
                    print("---------------------------------------------------------")
                    print(f"Se ha modificado el nombre de {nombre} a {nuevo_nombre}.")
                    print("---------------------------------------------------------")


                #Modificar el rango del Jedi
                elif opcion == "2":
                    print("Nuevo rango \n1. Padawan\n2. Caballero\n3. Maestro: ")# aqui tampoco he contemplado la opcion de que se de un valor distinto a 1, 2 o 3 ya que solo sale que hay 3 rangos en los Jedi
                    aux = input("> ")
                    if aux == "1":
                        nuevo_rango = "Padawan"
                    elif aux == "2":
                        nuevo_rango = "Caballero"
                    elif aux == "3":
                        nuevo_rango = "Maestro"
                    else:
                        print("Opción inválida. Por favor, elija una opción del menú.")
                        return
                    jedi.rango = nuevo_rango
                    print("---------------------------------------------------------")
                    print(f"Se ha modificado el rango de {nombre} a {nuevo_rango}.")
                    print("---------------------------------------------------------")

                #Modificar su nuevo poder
                elif opcion == "3":
                    nuevo_nivel_poder = input("Nuevo nivel de poder: ")
                    jedi.nivel_poder = nuevo_nivel_poder
                    print("---------------------------------------------------------")
                    print(f"Se ha modificado el nivel de poder de {nombre} a {nuevo_nivel_poder}.")
                    print("---------------------------------------------------------")

                #Modificar el nuevo maestro del Jedi
                elif opcion == "4":
                  nuevo_alumno_de = input("Escribe quien es su nuevo maestro: ")
                  jedi.alumno_de = nuevo_alumno_de
                  print("---------------------------------------------------------")
                  print(f"Se ha modificado el maestro de {nombre}, su nuevo maestro es {nuevo_alumno_de}")
                  print("---------------------------------------------------------")

                #Modificar el nuevo maestro del Jedi
                elif opcion == "5":
                  nuevo_maestro_de = input("Escribe el nuevo maaestro del Jedi: ")
                  jedi.maestro_de = nuevo_maestro_de
                  print("---------------------------------------------------------")
                  print(f"Se ha modificado de quien es maestro {nombre}, ahora es de {nuevo_maestro_de} ")
                  print("---------------------------------------------------------")
                else:
                  print("---------------------------------------------------------")
                  print("Opción inválida. Por favor, elija una opción del menú.")
                  print("---------------------------------------------------------")
                break
        else:
            print("---------------------------------------------------------")
            print(f"No se ha encontrado a {nombre} en la agenda de Jedis.")
            print("---------------------------------------------------------")


    #Creamos la opcion de modificar un Sith
    elif opcion == "2":
        nombre = input("Nombre: ")
        for sith in agenda_siths:
            if sith.nombre == nombre:
                print("---------------------------------------------------------")
                print("¿Qué desea modificar?")
                print("1. Nombre")
                print("2. Rango")
                print("3. Nivel de poder")
                print("4. Alumno de")
                print("5. Maestro de")
                print("---------------------------------------------------------")

                opcion = input("> ")

                    #Modificar el nombre para un sith
                if opcion == "1":
                    nuevo_nombre = input("Nuevo nombre: ")
                    if any (sith.nombre == nuevo_nombre for sith in agenda_siths):
                      print("-------------------------------------------")
                      print(f"{nuevo_nombre} ya esta en la agenda Siths.")
                      print("-------------------------------------------")
                      break
                    sith.nombre = nuevo_nombre
                    print("---------------------------------------------------------")
                    print(f"Se ha modificado el nombre de {nombre} a {nuevo_nombre}.")
                    print("---------------------------------------------------------")

                    #Modificar el rango de un sith
                elif opcion == "2":
                    print("Nuevo rango \n1. Aprendiz\n2. Darth\n3. Lord: ")# aqui tampoco he contemplado la opcion de que se de un valor distinto a 1, 2 o 3 ya que estos son los 3 rangos
                    aux = input("> ")
                    if aux == "1":
                        nuevo_rango = "Aprendiz"
                    elif aux == "2":
                        nuevo_rango = "Darth"
                    elif aux == "3":
                        nuevo_rango = "Lord"
                    else:
                        print("-------------------------------------------------------------")
                        print("ERROR: Opción inválida. Por favor, elija una opción del menú.")
                        print("-------------------------------------------------------------")
                        return
                    print("---------------------------------------------------------")
                    sith.rango = nuevo_rango
                    print(f"Se ha modificado el rango de {nombre} a {nuevo_rango}.")
                    print("---------------------------------------------------------")

                  #Modificar el nivel de poder del sith
                elif opcion == "3":
                    nuevo_nivel_poder = input("Nuevo nivel de poder: ")
                    sith.nivel_poder = nuevo_nivel_poder
                    print("---------------------------------------------------------")
                    print(f"Se ha modificado el nivel de poder de {nombre} a {nuevo_nivel_poder}.")
                    print("---------------------------------------------------------")

                  #Modificar el nuevo maestro del alumno
                elif opcion == "4":
                  nuevo_alumno_de = input("Escribe quien es su nuevo maestro: ")
                  sith.alumno_de = nuevo_alumno_de
                  print("---------------------------------------------------------")
                  print(f"Se ha modificado el maestro de {nombre}, su nuevo maestro es {nuevo_alumno_de}")
                  print("---------------------------------------------------------")

                  #Modificar el nuevo maestro del Sith introducido
                elif opcion == "5":
                  nuevo_maestro_de = input("Escribe el nuevo maestro del Sith: ")
                  sith.maestro_de = nuevo_maestro_de
                  print("---------------------------------------------------------")
                  print(f"Se ha modificado de quien es maestro {nombre}, ahora es de {nuevo_maestro_de} ")
                  print("---------------------------------------------------------")
                else:
                    print("---------------------------------------------------------")
                    print("ERROR: Opción inválida. Por favor, elija una opción del menú.")
                    print("---------------------------------------------------------")
                break
        else:
            print("---------------------------------------------------------")
            print(f"ERROR: No se ha encontrado a {nombre} en la agenda de Siths.")
            print("---------------------------------------------------------")
    else:
        print("---------------------------------------------------------")
        print("ERROR: Opción inválida. Por favor, elija una opción del menú.")
        print("---------------------------------------------------------")


#Definimos la funcion para poder consultar un sith o jedi

def consultar_sith_o_jedi():
    print("---------------------------------------------------------")
    print("¿Desea consultar un Jedi o un Sith?")
    print("1. Jedi")
    print("2. Sith")
    print("---------------------------------------------------------")

    opcion = input("> ")

#Creamos la opcion para poder consultar todos los datos de un Jedi

    if opcion == "1":
        nombre = input("Nombre: ")
        for jedi in agenda_jedis:
            if jedi.nombre == nombre:
                print("---------------------------------------------------------")
                print(f"Nombre: {jedi.nombre}")
                print(f"Rango: {jedi.rango}")
                print(f"Nivel de poder: {jedi.nivel_poder}")
                print(f"Alumno de: {jedi.alumno_de}")
                print(f"Maestro de: {jedi.maestro_de}")
                print("---------------------------------------------------------")
                break
        else:
            print("---------------------------------------------------------")
            print(f"ERROR: No se ha encontrado a {nombre} en la agenda de Jedis.")
            print("---------------------------------------------------------")

#Creamos la opcion para poder consultar todos los datos de un Sith

    elif opcion == "2":
        nombre = input("Nombre: ")
        for sith in agenda_siths:
            if sith.nombre == nombre:
                print("---------------------------------------------------------")
                print(f"Nombre: {sith.nombre}")
                print(f"Rango: {sith.rango}")
                print(f"Nivel de poder: {sith.nivel_poder}")
                print(f"Alumno de: {sith.alumno_de}")
                print(f"Maestro de: {sith.maestro_de}")
                print("---------------------------------------------------------")
                break
        else:
            print("---------------------------------------------------------")
            print(f"ERROR: No se ha encontrado a {nombre} en la agenda de Siths.")
            print("---------------------------------------------------------")
    else:
        print("---------------------------------------------------------")
        print("ERROR: Opción inválida. Por favor, elija una opción del menú.")
        print("---------------------------------------------------------")



#Definimos la funcion de eliminar un sith o un jedi

def eliminar_sith_o_jedi():
    print("---------------------------------------------------------")
    print("¿Desea eliminar un Jedi o un Sith?")
    print("1. Jedi")
    print("2. Sith")
    print("---------------------------------------------------------")

    opcion = input("> ")

#Creamos la opcion para poder borrar un Jedi

    if opcion == "1":
        nombre = input("Nombre: ")
        for jedi in agenda_jedis:
            if jedi.nombre == nombre:
                agenda_jedis.remove(jedi)
                print("----------------------------------------------------")
                print(f"Se ha eliminado a {nombre} de la agenda de Jedis.")
                print("----------------------------------------------------")
                break
        else:
            print("------------------------------------------------------")
            print(f"ERROR: No se ha encontrado a {nombre} en la agenda de Jedis.")
            print("------------------------------------------------------")

#Creamos la opcion para poder borrar un Sith

    elif opcion == "2":
        nombre = input("Nombre: ")
        for sith in agenda_siths:
            if sith.nombre == nombre:
                agenda_siths.remove(sith)
                print("--------------------------------------------------")
                print(f"Se ha eliminado a {nombre} de la agenda de Siths.")
                print("--------------------------------------------------")
                break
        else:
            print("-------------------------------------------------------------")
            print(f"ERROR: No se ha encontrado a {nombre} en la agenda de Siths.")
            print("-------------------------------------------------------------")
    else:
        print("------------------------------------------------------")
        print("Opción inválida. Por favor, elija una opción del menú.")
        print("------------------------------------------------------")


#Definimos la funcion para poder buscar un sith o jedi

def buscar_sith_o_jedi():
    print("-----------------------------------------------")
    print("¿Desea buscar un Jedi o un Sith?")
    print("1. Jedi")
    print("2. Sith")
    print("-----------------------------------------------")

    opcion_1 = input("> ")
#En caso de que sea Jedi
    if opcion_1 == "1":
        print("--------------------------------------")
        print("¿Qué desea buscar?")
        print("1. Nombre")
        print("2. Rango")
        print("3. Nivel de poder")
        print("--------------------------------------")

        opcion_2 = input("> ")

        if opcion_2 == "1":
            nombre = input("Nombre: ")
            for jedi in agenda_jedis:
                if jedi.nombre == nombre:
                    print(f"Nombre: {jedi.nombre}")
                    print(f"Rango: {jedi.rango}")
                    print(f"Nivel de poder: {jedi.nivel_poder}")
                    print(f"Alumno de: {jedi.alumno_de}")
                    print(f"Maestro de: {jedi.maestro_de}")
                    print("-------------------------------")
            else:
                print(f"No se ha encontrado a {nombre} en la agenda de Jedis.")

        elif opcion_2 == "2":
            rango = input("Rango: ")
            for jedi in agenda_jedis:
                if jedi.rango == rango:
                    print(f"Nombre: {jedi.nombre}")
                    print(f"Rango: {jedi.rango}")
                    print(f"Nivel de poder: {jedi.nivel_poder}")
                    print(f"Alumno de: {jedi.alumno_de}")
                    print(f"Maestro de: {jedi.maestro_de}")
                    print("-------------------------------")
            else:
                print(f"No se ha encontrado a ningún Jedi con rango {rango} en la agenda de Jedis.")

        elif opcion_2 == "3":
            nivel_poder = input("Nivel de poder: ")
            for jedi in agenda_jedis:
                if jedi.nivel_poder == nivel_poder:
                    print(f"Nombre: {jedi.nombre}")
                    print(f"Rango: {jedi.rango}")
                    print(f"Nivel de poder: {jedi.nivel_poder}")
                    print(f"Alumno de: {jedi.alumno_de}")
                    print(f"Maestro de: {jedi.maestro_de}")
                    print("-------------------------------")
            else:
                print(f"No se ha encontrado a ningún Jedi con nivel de poder {nivel_poder} en la agenda de Jedis.")

        else:
            print("Opción inválida. Por favor, elija una opción del menú.")

    elif opcion_1 == "2":
        print("-----------------------------------")
        print("¿Qué desea buscar?")
        print("1. Nombre")
        print("2. Rango")
        print("3. Nivel de poder")
        print("-----------------------------------")

        opcion_2 = input("> ")

        if opcion_2 == "1":
            nombre = input("Nombre: ")
            for sith in agenda_siths:
                if sith.nombre == nombre:
                    print(f"Nombre: {sith.nombre}")
                    print(f"Rango: {sith.rango}")
                    print(f"Nivel de poder: {sith.nivel_poder}")
                    print(f"Alumno de: {sith.alumno_de}")
                    print(f"Maestro de: {sith.maestro_de}")
                    print("-------------------------------")
            else:
                print(f"No se ha encontrado a {nombre} en la agenda de Siths.")

        elif opcion_2 == "2":
            rango = input("Rango: ")
            for sith in agenda_siths:
              if sith.rango == rango:
                  print(f"Nombre: {sith.nombre}")
                  print(f"Rango: {sith.rango}")
                  print(f"Nivel de poder: {sith.nivel_poder}")
                  print(f"Alumno de: {sith.alumno_de}")
                  print(f"Maestro de: {sith.maestro_de}")
                  print("--------------------------------")
            else:
               print(f"No se ha encontrado a ningun Sith con ese {rango} en la agenda de Siths.")

    elif opcion_2 == "3":
        nivel_poder = input("Nivel de poder: ")
        for sith in agenda_siths:
            if sith.nivel_poder == nivel_poder:
                print(f"Nombre: {sith.nombre}")
                print(f"Rango: {sith.rango}")
                print(f"Nivel de poder: {sith.nivel_poder}")
                print(f"Alumno de: {sith.alumno_de}")
                print(f"Maestro de: {sith.maestro_de}")
                print("-------------------------------")
        else:
            print(f"No se ha encontrado a ningun Sith con ese {nivel_poder} en la agenda de Siths.")

    else:
        print("Opción inválida. Por favor, elija una opción del menú.")


# Definir función para mostrar todos los sith/jedi de la agenda
def mostrar_todos_los_sith_o_jedi():
    print("Jedis:")
    for jedi in agenda_jedis:
        print(f"Nombre: {jedi.nombre}")
        print(f"Rango: {jedi.rango}")
        print(f"Nivel de poder: {jedi.nivel_poder}")
        print(f"Alumno de: {jedi.alumno_de}")
        print(f"Maestro de: {jedi.maestro_de}")
        print("-------------------------------------------------------------")

    print("Siths:")
    for sith in agenda_siths:
        print(f"Nombre: {sith.nombre}")
        print(f"Rango: {sith.rango}")
        print(f"Nivel de poder: {sith.nivel_poder}")
        print(f"Alumno de: {sith.alumno_de}")
        print(f"Maestro de: {sith.maestro_de}")
        print("-------------------------------------------------------------")

# Menú principal
while True:
    print("Elija una opción:")
    print("1. Añadir un nuevo sith/jedi a la agenda")
    print("2. Modificar un sith/jedi existente")
    print("3. Consultar los datos de un sith/jedi")
    print("4. Eliminar un sith/jedi")
    print("5. Buscar por nombre, por rango o por nivel de poder")
    print("6. Mostrar todos los sith/jedi de la agenda")
    print("7. Salir")

    opcion = input("> ")

    if opcion == "1":
        anadir_sith_o_jedi()
    elif opcion == "2":
        modificar_sith_o_jedi()
    elif opcion == "3":
        consultar_sith_o_jedi()
    elif opcion == "4":
        eliminar_sith_o_jedi()
    elif opcion == "5":
        buscar_sith_o_jedi()
    elif opcion == "6":
        mostrar_todos_los_sith_o_jedi()
    elif opcion == "7":
        print("¡Hasta luego! Que la fuerza este contigo. Muchas gracias," , (name))
        starwars2 = r"""

⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣤⣤⠤⠐⠂⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡌⡦⠊⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡀⣼⡊⢀⠔⠀⠀⣄⠤⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣤⣤⣄⣀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⣶⠃⠉⠡⡠⠤⠊⠀⠠⣀⣀⡠⠔⠒⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⣾⣿⢟⠿⠛⠛⠁
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣼⡇⠀⠀⠀⠀⠑⠶⠖⠊⠁⠀⠀⠀⡀⠀⠀⠀⢀⣠⣤⣤⡀⠀⠀⠀⠀⠀⢀⣠⣤⣶⣿⣿⠟⡱⠁⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢰⣾⣿⡇⠀⢀⡠⠀⠀⠀⠈⠑⢦⣄⣀⣀⣽⣦⣤⣾⣿⠿⠿⠿⣿⡆⠀⠀⢀⠺⣿⣿⣿⣿⡿⠁⡰⠁⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣾⣿⣿⣧⣠⠊⣠⣶⣾⣿⣿⣶⣶⣿⣿⠿⠛⢿⣿⣫⢕⡠⢥⣈⠀⠙⠀⠰⣷⣿⣿⣿⡿⠋⢀⠜⠁⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠠⢿⣿⣿⣿⣿⣰⣿⣿⠿⣛⡛⢛⣿⣿⣟⢅⠀⠀⢿⣿⠕⢺⣿⡇⠩⠓⠂⢀⠛⠛⠋⢁⣠⠞⠁⠀⠀⠀⠀⠀⠀⠀⠀
⠘⢶⡶⢶⣶⣦⣤⣤⣤⣤⣤⣀⣀⣀⣀⡀⠀⠘⣿⣿⣿⠟⠁⡡⣒⣬⢭⢠⠝⢿⡡⠂⠀⠈⠻⣯⣖⣒⣺⡭⠂⢀⠈⣶⣶⣾⠟⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠙⠳⣌⡛⢿⣿⣿⣿⣿⣿⣿⣿⣿⣻⣵⣨⣿⣿⡏⢀⠪⠎⠙⠿⣋⠴⡃⢸⣷⣤⣶⡾⠋⠈⠻⣶⣶⣶⣷⣶⣷⣿⣟⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠈⠛⢦⣌⡙⠛⠿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡀⠀⠀⠩⠭⡭⠴⠊⢀⠀⠀⠀⠀⠀⠀⠀⠀⠈⣿⣿⣿⣿⣿⡇⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠈⠙⠓⠦⣄⡉⠛⠛⠻⢿⣿⣿⣿⣷⡀⠀⠀⠀⠀⢀⣰⠋⠀⠀⠀⠀⠀⣀⣰⠤⣳⣿⣿⣿⣿⣟⠑⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠓⠒⠒⠶⢺⣿⣿⣿⣿⣦⣄⣀⣴⣿⣯⣤⣔⠒⠚⣒⣉⣉⣴⣾⣿⣿⣿⣿⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛⠹⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠙⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣭⣉⣉⣤⣿⣿⣿⣿⣿⣿⡿⢀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⠟⡁⡆⠙⢶⣀⠀⢀⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣀⣴⣶⣾⣿⣟⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠿⢛⣩⣴⣿⠇⡇⠸⡆⠙⢷⣄⠻⣿⣦⡄⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣼⣿⣿⣿⣿⣿⣿⣿⣎⢻⣿⣿⣿⣿⣿⣿⣿⣭⣭⣭⣵⣶⣾⣿⣿⣿⠟⢰⢣⠀⠈⠀⠀⠙⢷⡎⠙⣿⣦⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣼⣿⣿⣿⣿⣿⣿⣿⣿⡟⣿⡆⢻⣿⣿⣿⣿⣿⣿⣿⣿⣿⠿⠿⠟⠛⠋⠁⢀⠇⢸⡇⠀⠀⠀⠀⠈⠁⠀⢸⣿⡆⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡜⡿⡘⣿⣿⣿⣿⣿⣶⣶⣤⣤⣤⣤⣤⣤⣤⣴⡎⠖⢹⡇⠀⠀⠀⠀⠀⠀⠀⠀⣿⣷⡄⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣦⡀⠘⢿⣿⣿⣿⣿⣿⣿⣿⣿⠿⠿⠛⠋⡟⠀⠀⣸⣷⣀⣤⣀⣀⣀⣤⣤⣾⣿⣿⣿⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⣸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣭⣓⡲⠬⢭⣙⡛⠿⣿⣿⣶⣦⣀⠀⡜⠀⠀⣰⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡇⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⢀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣭⣛⣓⠶⠦⠥⣀⠙⠋⠉⠉⠻⣄⣀⣸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡇⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⣼⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣶⣆⠐⣦⣠⣷⠊⠁⠀⠀⡭⠙⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡆⠀⠀
⠀⠀⠀⠀⠀⠀⠀⢠⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⢉⣛⡛⢻⡗⠂⠀⢀⣷⣄⠈⢆⠉⠙⠻⢿⣿⣿⣿⣿⣿⠇⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠘⣿⣿⡟⢻⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡟⣉⢁⣴⣿⣿⣿⣾⡇⢀⣀⣼⡿⣿⣷⡌⢻⣦⡀⠀⠈⠙⠛⠿⠏⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠙⢿⣿⡄⠙⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠿⠛⠛⠛⢯⡉⠉⠉⠉⠉⠛⢼⣿⠿⠿⠦⡙⣿⡆⢹⣷⣤⡀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠿⠄⠈⠻⠿⠿⠿⠿⠿⠿⠛⠛⠿⠛⠉⠁⠀⠀⠀⠀⠀⠀⠻⠿⠿⠿⠿⠟⠉⠀⠀⠤⠴⠶⠌⠿⠘⠿⠿⠿⠿⠶⠤⠀⠀⠀⠀

        """
        print(starwars2)
        break
    else:
        print("Opción inválida. Por favor, elija una opción del menú.")
# Out:
# ¡Hola! Introduce tu nombre: nico
# ¡Bienvenido a tu Agenda de Star Wars, nico
#
#   ⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⠀⢀⣤⣤⣤⣤⣤⣤⣤⠀⠀⠀⠀⢠⣤⣤⣤⣤⣤⣤⣤⣤⣤⣤⣀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠀⣼⣿⣿⣿⣿⣿⣿⣿⣇⠀⠀⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⡀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣟⠛⠛⠛⠛⠛⣿⣿⣿⣿⡟⠛⠛⠛⠛⠛⢠⣿⣿⣿⣿⠿⣿⣿⣿⣿⡀⠀⠀⢸⣿⣿⣿⣿⡏⠉⠉⢉⣿⣿⣿⣿⡇⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠙⢿⣿⣿⣿⣿⣷⡀⠀⠀⠀⣿⣿⣿⣿⡇⠀⠀⠀⠀⠀⣾⣿⣿⣿⡟⠀⢻⣿⣿⣿⣧⠀⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠟⠀⠀⠀⠀⠀
# ⣤⣤⣤⣤⣤⣤⣤⣤⣤⣬⣿⣿⣿⣿⣿⣷⠀⠀⠀⣿⣿⣿⣿⡇⠀⠀⠀⠀⢰⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡆⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣧⣤⣤⣤⣤⣤⣤
# ⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠏⠀⠀⠀⣿⣿⣿⣿⡇⠀⠀⠀⢀⣿⣿⣿⣿⡿⠿⠿⠿⠿⣿⣿⣿⣿⡀⢸⣿⣿⣿⣿⡇⠙⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
# ⠿⠿⠿⠿⠿⠿⠿⠿⠿⠿⠿⠿⠟⠛⠁⠀⠀⠀⠀⠿⠿⠿⠿⠇⠀⠀⠀⠸⠿⠿⠿⠟⠀⠀⠀⠀⠀⠻⠿⠿⠿⠇⠸⠿⠿⠿⠿⠇⠀⠀⠙⠛⠿⠿⠿⠿⠿⠿⠿⠿
# ⢻⣿⣿⣿⣿⡄⢠⣿⣿⣿⣿⣿⡆⠀⣾⣿⣿⣿⡟⠀⢀⣾⣿⣿⣿⣿⣿⣿⡄⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣷⣶⣦⣄⠀⠀⠀⠀⣠⣶⣶⣿⣿⣿⣿⣿⣿⣿⣿
# ⠈⣿⣿⣿⣿⣷⣼⣿⣿⣿⣿⣿⣿⣸⣿⣿⣿⣿⠁⠀⣼⣿⣿⣿⣿⣿⣿⣿⣷⠀⠀⠀⠀⣿⣿⣿⣿⣿⠿⠿⢿⣿⣿⣿⣿⣇⠀⠀⣸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
# ⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡏⠀⢠⣿⣿⣿⣿⠏⢿⣿⣿⣿⣇⠀⠀⠀⣿⣿⣿⣿⣿⣀⣀⣀⣼⣿⣿⣿⡟⠀⠀⢹⣿⣿⣿⣿⣿⣄⠀⠀⠀⠀⠀
# ⠀⠀⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠀⠀⣾⣿⣿⣿⣟⣀⣸⣿⣿⣿⣿⡀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⠟⠁⠀⠀⠀⠙⢿⣿⣿⣿⣿⣧⠀⠀⠀⠀
# ⠀⠀⠘⣿⣿⣿⣿⣿⣿⠋⣿⣿⣿⣿⣿⣿⠇⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣧⠀⠀⣿⣿⣿⣿⣿⢿⣿⣿⣿⣿⣿⣶⣶⣶⣶⣶⣶⣾⣿⣿⣿⣿⣿⠇⠀⠀⠀
# ⠀⠀⠀⢻⣿⣿⣿⣿⡏⠀⢹⣿⣿⣿⣿⡟⠀⢀⣿⣿⣿⣿⡟⠛⠛⠛⠛⣿⣿⣿⣿⡆⠀⣿⣿⣿⣿⣿⠀⠙⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠟⠀⠀⠀⠀
# ⠀⠀⠀⠈⠉⠉⠉⠉⠀⠀⠀⠉⠉⠉⠉⠁⠀⠈⠉⠉⠉⠉⠀⠀⠀⠀⠀⠉⠉⠉⠉⠉⠀⠉⠉⠉⠉⠉⠀⠀⠀⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠁⠀⠀⠀⠀⠀⠀⠀⠀
#
#
# Elija una opción:
# ...
